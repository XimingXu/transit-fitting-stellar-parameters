# %%
# Set up a new environment and install the BASTA package

# !pip install basta
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 571.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 754.8/754.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 27.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
# ...

# %%
# Download a precomputed stellar model grid and obtain the dustmaps
# Allowed_grids: '16CygA', 'validation', 'iso', 'validation_new-weights'

# !BASTAdownload 'iso'
# Out:
# /usr/local/lib/python3.11/dist-packages/dustmaps/config.py:74: ConfigWarning: Configuration file not found:
#
#     /root/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
#   warn(('Configuration file not found:\n\n'
# ...
# --> Progress: 100% 12.0G/12.0G [13:54<00:00, 15.4MB/s]
# Decompressing grid into '/content/grids/BaSTI_iso2018.hdf5' ... done!
#
# ...
# Location of dustmaps: /content/dustmaps
# Obtaining dustmaps!
#
# Fetching the SFD dustmap ...
#
# ...
#  63.2 MiB of 64.0 MiB |  23.3 MiB/s |################## |  98% | ETA:   0:00:00Downloading SFD data file to /content/dustmaps/sfd/SFD_dust_4096_sgp.fits
# ...
#  62.4 MiB of 64.0 MiB |  24.8 MiB/s |################## |  97% | ETA:   0:00:00
# Done!
# ----------
#
# ...

# %%
# Upload the target's ASCII file (e.g., 'WASP-17 (light curve-based model).ascii')
# Then run the corresponding one of the following three files to generate an XML input file for BASTA
# Remember to update the target name and ODEA settings as needed in the corresponding files

#! python spectroscopy_based_model.py
! python light_curve_based_model.py
#! python combined_model.py
# Out:
# **********************************************
# *** Generating an XML input file for BASTA ***
# **********************************************
#
# Reading user input ...
# Done!
#
# Running consistency checks ...
# Done!
#
# Creating XML input file 'input_myfit.xml' ...
# Done!
#
#
#    Summary of the requested BASTA run
# ----------------------------------------
#
# A total of 1 star(s) will be fitted with {r, h, o} to the grid '/content/grids/BaSTI_iso2018.hdf5'.
# Using the isochrone science case (overshooting=0.2, diffusion=0, mass loss eta=0, enhancement alphaFe=0).
#
# This will output {rho, radPhot, massfin, age} to a results file.
# A .json file per star will be saved with calculated statistics.
#
# Corner plots include {rho, radPhot, massfin, age} with observational bands on {r, h, o}.
# Kiel diagrams will be made with observational bands on {r, h, o}.
#
# A restricted flat prior will be applied to: rho.
#
# ...

# %%
# Once the input_myfit.xml file has been correctly created, simply run BASTA
# The output files (e.g., 'WASP-17 light curve-based model output') will then be stored in the designated location

! BASTArun input_myfit.xml
# Out:
# ...
#                                          BASTA
#                              The BAyesian STellar Algorithm
#
#                                      Version 1.5.3
#
#                                 (c) 2024, The BASTA Team
#                            https://github.com/BASTAcode/BASTA
# ...
#
# Run started on 2025-05-09 19:29:01 .
#
# Random numbers initialised with seed: 1433 .
#
# Fitting star id: WASP-17 .
# * Using the grid '/content/grids/BaSTI_iso2018.hdf5' of type 'isochrones'.
#   - Grid built with BASTA version 1.1.4, timestamp: 2022-09-12 at 17:48:37.
#
# Transforming solar-based asteroseismic quantities:
# * Converting to solar units if needed...
# * Solar model scaling not activated!  -->  Dnu will not be scaled.
# Done!
#
# Fitting information:
# * Fitting parameters with values and uncertainties:
#   - rho: [0.5043, 0.03]
#
# Additional input parameters and settings in alphabetical order:
# * asciiparams: ['rho', 'radPhot', 'massfin', 'age']
# * centroid: median
# ...
